# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df=pd.read_csv("E:/Courses/AI/Data Science/New folder/tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.lmplot('total_bill','tip',data=df)

# %%
sb.lmplot('total_bill','tip',data=df, hue='sex')

# %%
sb.lmplot('total_bill','tip',data=df, hue='sex', markers=['o','+'])

# %%
sb.lmplot('total_bill','tip',data=df, col='sex')
